# %%
x=
print(x)
type(x)
# Out:
# smit
# str

# %%
mon=[22,7,9,9,5,6]
mon[3]=5
mon
mon.append('sm')
mon

mon.pop()
mon[1]="lii"

# %%
name1=('ram',9870,'jaipur')
name1=('jai')
name1
# Out:
# 'jai'

# %%
import numpy as np
db=[ 
     ["tom", 11111,"ok"],
     ["rahul",22222,"good"],
     ["krish",33333,"vgood"],
     ["pop",44444,"ok"]
]

# %%
arr=np.array(db)
print(arr[:,1])
# Out:
# ['11111' '22222' '33333' '44444']

# %%
len(db)
# Out:
# 4
